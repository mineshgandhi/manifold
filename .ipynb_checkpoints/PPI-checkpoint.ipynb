# %%
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn import manifold, datasets
from scipy import sparse, io
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import mat4py
from LE import LE
import glob
import pandas as pd

# %%
PPI = io.loadmat('PPI.mat')
pip_src = mat4py.loadmat('PPI.mat')
# print(PPI)
# data = digits.shape
print(PPI['G']['am'][0][0][0].shape)
print(PPI['G']['al'][0][0][0][0].shape)
print(PPI['G']['nl'][0][0][0][0][0][0].shape)

print(PPI['G']['am'].shape)
print(PPI['G']['al'].shape)
print(PPI['G']['nl'].shape)

print(PPI['labels'].shape)
# labels = PPI.labels
print(pip_src['G'].keys())

data = PPI['labels']
print(data.shape[1])
# Out:
# (161,)
# (1, 66)
# (1,)
# (1, 86)
# (1, 86)
# (1, 86)
# (86, 1)
# dict_keys(['am', 'al', 'nl'])
# 1

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
# number of points
n = data_.shape[0]

# dimension of embedding
d = 3

# number of neighbours
k = 86
path = 'PPI'
files = glob.glob(path + '/*.csv')

lists = []

for filename in files:
    df = pd.read_csv(filename, index_col=None, header=None)
    lists.append(df)
    
frame = pd.concat(lists, axis=0, ignore_index=True)
data_ = clean_dataset(frame)

labels = pd.read_csv('ppi_labels.csv').T
# labels = labels.values.flatten()

data_, labels = data_.align(labels, axis=1, fill_value=0)

labels = labels.T
print(labels.shape)
print(data_.shape)
# Out:
# (232, 1)
# (232, 232)

# %%
le_ppi = LE(data_, eps = 33, dim = 3, graph = 'eps', weights = 'heat kernel', 
               sigma = 5, laplacian = 'symmetrized', opt_eps_jumps = 1.2)

print(le_ppi)
Y_ppi = le_ppi.transform()
# Out:
# <LE.LE object at 0x7f77a0c52ca0>

# %%
fig = plt.figure(figsize = (15,18))
ax = fig.add_subplot(111, projection='3d')
ax3d = ax.scatter(Y_ppi[:, 0], Y_ppi[:, 1], Y_ppi[:, 2], c=labels,cmap=plt.cm.get_cmap('jet', 10))
fig.colorbar(ax3d, ticks=range(10), aspect = 2, fraction = 0.1)
plt.title('LE with $\epsilon$ = {} and weights = {}'.format(le_ppi.eps, le_ppi.weights))
plt.show()

# %%
X, color = datasets.make_swiss_roll(n_samples=2000, random_state = 2456)
# (n_samples=100, *, noise=0.0, random_state=None)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(7, -80)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.jet)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# Text(0.5, 0, 'Z Label')

# %%
le = LE(X, dim = 3, eps = 1.97, graph = 'eps', weights = 'heat kernel', 
        sigma = 5, laplacian = 'symmetrized')

# %%
Y_t = le.transform()

# %%
'''all-purpose diffusion map code'''

# number of points
n = hgt.shape[0]

# neighbour search (replace with your favourite algorithm)
knn = NearestNeighbors(n_neighbors=k).fit(data_)

_, jj = knn.kneighbors(data_)

ii = np.repeat(range(0, n), k)
print(ii.shape)
# affinity matrix (W(x, y) is the number of neighbours x and y have in common)
W = sparse.coo_matrix((np.ones(n * k), (ii, jj.ravel())))
print(W)
W = W * W.transpose()

# alpha normalization (cancels non-uniform density)
D = sparse.diags(1 / W.sum(axis=1).A.ravel())
W = D * W * D

# isotropic kernel P = I - L^sym <-- symmetric normalized graph laplacian
D = sparse.diags(1 / np.sqrt(W.sum(axis=1)).A.ravel())
P = D * W * D

# eigendecomposition
_, E = sparse.linalg.eigsh((P + P.transpose()) / 2, k=d+1, which='LM')

# shift back to get diffusion embedding (unnormalized eigenvectors of diffusion kernel)
E = D * E[:, :-1]

# visualize embedding
if d < 3:
    plt.scatter(E[:, 0], E[:, 1], c=np.linspace(0, 1, n), cmap='jet')
else:
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.scatter(E[:, 0], E[:, 1], E[:, 2], c=np.linspace(0, 1, n), cmap='jet')
  
plt.show()
# Out:
# (2314432,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-eef312f1595e> in <module>
#      12 print(ii.shape)
#      13 # affinity matrix (W(x, y) is the number of neighbours x and y have in common)
# ---> 14 W = sparse.coo_matrix((np.ones(n * k), (ii, jj.ravel())))
#      15 print(W)
#      16 W = W * W.transpose()
#
# /mnt/1C10BE5A463AA9E0/ProjectsDir/ML/Manifold Learning/venv/lib/python3.8/site-packages/scipy/sparse/coo.py in __init__(self, arg1, shape, dtype, copy)
#     195             self.data = self.data.astype(dtype, copy=False)
#     196
# --> 197         self._check()
#     198
#     199     def reshape(self, *args, **kwargs):
#
# /mnt/1C10BE5A463AA9E0/ProjectsDir/ML/Manifold Learning/venv/lib/python3.8/site-packages/scipy/sparse/coo.py in _check(self)
#     280         self.data = to_native(self.data)
#     281
# --> 282         if self.nnz > 0:
#     283             if self.row.max() >= self.shape[0]:
#     284                 raise ValueError('row index exceeds matrix dimensions')
#
# /mnt/1C10BE5A463AA9E0/ProjectsDir/ML/Manifold Learning/venv/lib/python3.8/site-packages/scipy/sparse/base.py in nnz(self)
#     244         count_nonzero : Number of non-zero entries
#     245         """
# --> 246         return self.getnnz()
#     247
#     248     def getformat(self):
#
# /mnt/1C10BE5A463AA9E0/ProjectsDir/ML/Manifold Learning/venv/lib/python3.8/site-packages/scipy/sparse/coo.py in getnnz(self, axis)
#     242             nnz = len(self.data)
#     243             if nnz != len(self.row) or nnz != len(self.col):
# --> 244                 raise ValueError('row, column, and data array must all be the '
#     245                                  'same length')
#     246
#
# ValueError: row, column, and data array must all be the same length
